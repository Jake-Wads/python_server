# %%
import os
# SQL LOGIN
host = os.getenv('sqlHOST')
user = os.getenv('sqlUSER')
password = os.getenv('sqlPSWD')

# %% [markdown]
# # Exercises: Hypothesis Testing - COMPARISON OF GROUPS: $χ^2$
#
# <a href = "https://ds.codeup.com/stats/compare-group-membership/#exercises">![image.png](attachment:69c94aad-2e23-4cd2-9ce9-0555fc19ae2c.png)</a>
#
# <hr style="border:2px solid gray">

# %%
import pandas as pd
import numpy as np

from scipy import stats
#import env

# %% [markdown]
# # 1. Use the following contingency table to help answer the question of whether using a macbook and being a codeup student are independent of each other.
#
# |                       | Codeup Student | Not Codeup Student |
# |-----------------------|----------------|--------------------|
# | Uses a Macbook        | 49             | 20                 |
# | Doesn't Use a Macbook | 1              | 30                 |

# %% [markdown]
# ## a. Form hypotheses

# %% [markdown]
# $H_o$:
#
# $H_a$:

# %% [markdown]
# ##  b. State your alpha (𝞪)

# %%
alpha =

# %% [markdown]
# ### Make contigency tables

# %% [markdown]
# ##  c. Perform a $chi^2$ test of independence:
# ### Calculate chi2 and p-value

# %% [markdown]
# ## d. State your conclusion

# %% [markdown]
# # 2. Choose another 2 categorical variables from the mpg dataset and perform a chi2 contingency table test with them. Be sure to state your null and alternative hypotheses.

# %%
from pydataset import data

# %%
#import data from pydataset

# %%
#look at info

# %%
#use .nunique to see which columns have categorical variables

# %%
#look at year data

# %%
#look at cyl data

# %% [markdown]
# ## 2a. Form hypotheses

# %% [markdown]
# $H_o$:
#
# $H_a$:

# %% [markdown]
# ##  2b. State your alpha (𝞪)

# %% [markdown]
# ### Make contigency tables

# %% [markdown]
# ##  2c. Perform a $chi^2$ test of independence:
# ### Calculate chi2 and p-value

# %% [markdown]
# ## 2d. State your conclusion

# %% [markdown]
# # 3. Use the data from the employees database to answer these questions:

# %%
import env

def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %% [markdown]
# ## 3a. Is an employee's gender independent of whether an employee works in sales or marketing? (only look at current employees)

# %% [markdown]
# $H_o$:
#
# $H_a$:

# %%
#set sql query
query =

# %%
#read in sql data

# %%
#view gender data

# %%
#view dept_name data

# %%
#create contigency table

# %%
#calculate chi2 and p-value

# %% [markdown]
# ## 3b. Is an employee's gender independent of whether or not they are or have been a manager?

# %% [markdown]
# $H_o$:
#
# $H_a$:

# %%
#set sql query
query =

# %%
#read in sql data

# %%
#look at data

# %%
#look at dept_no data

# %%
#fill in nulls

# %%
#make new column using np.where
# np.where( condtion, this happens when true, this happens when false)

# %%
#create contigency table

# %%
#calculate chi2 and p-value

# %% [markdown]
# # Helpful function
