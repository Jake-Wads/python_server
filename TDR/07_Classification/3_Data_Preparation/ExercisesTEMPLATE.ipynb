# %% [markdown]
# # Exercises: Classification - PREPARATION
#
# <a href = "https://ds.codeup.com/classification/prep/#exercises">![image.png](attachment:15b0e2aa-6935-4cb6-9e72-204b96f7ea6c.png)</a>
#
# <hr style="border:2px solid gray">

# %%
#standard ds libraries
import pandas as pd
import os
#import env

#acquire module
import acquire

# import splitting functions
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Initial Instructions
# The end product of this exercise should be the specified functions in a python script named `prepare.py`. Do these in your `classification_exercises.ipynb` first, then transfer to the prepare.py file.
#
# This work should all be saved in your local `classification-exercises` repo. Then add, commit, and push your changes.

# %% [markdown]
# ___
# # Using the Iris Data:

# %% [markdown]
# ## I1. Use the function defined in acquire.py to load the iris data.

# %% [markdown]
# ## I2. Drop the species_id and measurement_id columns.

# %% [markdown]
# ## I3. Rename the species_name column to just species.

# %% [markdown]
# ## I4. Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %% [markdown]
# ## I5. Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %% [markdown]
# ___
# # Using the Titanic dataset

# %% [markdown]
# ## T1. Use the function defined in acquire.py to load the Titanic data.

# %% [markdown]
# ## T2. Drop any unnecessary, unhelpful, or duplicated columns.

# %% [markdown]
# ## T3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %% [markdown]
# ## T4. Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %% [markdown]
# ___
# # Using the Telco Churn dataset

# %% [markdown]
# ## C1. Use the function defined in acquire.py to load the Telco data.

# %% [markdown]
# ## C2. Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %% [markdown]
# ## C3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %% [markdown]
# ## C4. Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %% [markdown]
# ___
# # Split your data

# %% [markdown]
# ## S1. Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %% [markdown]
# ## S2. Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %% [markdown]
# ## S3. Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %% [markdown]
# ## S4. Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.
