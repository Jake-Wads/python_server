# %%
import os
# SQL LOGIN
host = os.getenv('sqlHOST')
user = os.getenv('sqlUSER')
password = os.getenv('sqlPSWD')

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <strong> Instructor Note:</strong>
#
# RELEASE `Classification Lesson - students.csv` DATA FILE <b>PRIOR</b> TO LESSON!!!
# ![image.png](attachment:40e127e9-ab33-421f-95ab-03da1542de4d.png)
#
# </div>

# %% [markdown]
# # Lesson: Classification - ACQUISITION
#
# <a href = "https://ds.codeup.com/classification/acquire/">![image.png](attachment:ac2aa2bd-8053-4771-8263-c418193d8a74.png)</a>
#
# <hr style="border:2px solid gray">

# %% [markdown]
# # Methods of Data Acquisition
#
# ### 1. `read_clipboard`:
# - When you have data copied to your clipboard, you can use pandas to read it into a data frame with pd.read_clipboard. This can be useful for quickly transferring data to/from a spreadsheet.
#
# <br>
#
# ### 2. `read_csv`:
# - Read from a local csv, or from a the cloud (Google Sheets or AWS S3).
#
# <br>
#
# ### 3. `read_excel`:
# - This function can be used to create a data frame based on the contents of an Excel spreadsheet.
#
# <br>
#
# ### 4. `read_sql(sql_query, connection_url)`:
# - Read data using a SQL query to a database. You must have the required drivers installed, and a specially formatted url string must be provided.
#
#     >To talk to a mysql database:
#     >
#     >` python -m pip install pymysql mysql-connector`
#     <br>
#     >The connection url string:
#     >
#     >` mysql+pymysql://{USER}:{PASSWORD}@{HOST}/{DATABASE_NAME}`

# %% [markdown]
# ___
# # Source: Clipboard
#
# Navigate to Google Classroom > Classwork > Data
#
# - Scroll down to Classification Lesson - students.csv
# - Double click to Open
# - [Cmd][A]
# - [Cmd][C]

# %%
import pandas as pd 
#import env

# %%
df1 = pd.read_clipboard()
df1
# Out:
#        date                 var          val
# 0    2/4/19   n_late_from_break     4.028120
# 1    2/4/19  coffee_consumption  5255.409740
# 2    2/4/19      classroom_temp    67.000000
# 3    2/5/19   n_late_from_break     2.101998
# 4    2/5/19  coffee_consumption  8603.704720
# 5    2/5/19      classroom_temp    73.000000
# 6    2/6/19   n_late_from_break     4.941244
# 7    2/6/19  coffee_consumption  1801.498050
# 8    2/6/19      classroom_temp    81.000000
# 9    2/7/19   n_late_from_break     1.419342
# 10   2/7/19  coffee_consumption  9282.959740
# 11   2/7/19      classroom_temp    62.000000
# 12   2/8/19  coffee_consumption  7558.270660
# 13   2/8/19      classroom_temp    72.000000
# 14   2/8/19   n_late_from_break     1.808919
# 15  2/11/19      classroom_temp    60.000000
# 16  2/11/19  coffee_consumption  5731.008710
# 17  2/11/19   n_late_from_break     4.831584
# 18  2/12/19  coffee_consumption  9547.673480
# 19  2/12/19      classroom_temp    52.000000
# 20  2/12/19   n_late_from_break     3.550830
# 21  2/13/19  coffee_consumption  7114.931850
# 22  2/13/19      classroom_temp    56.000000
# 23  2/13/19   n_late_from_break     2.550362
# 24  2/14/19  coffee_consumption  1977.295510
# 25  2/14/19      classroom_temp    72.000000
# 26  2/14/19   n_late_from_break     3.507548
# 27  2/15/19   n_late_from_break     2.114379
# 28  2/15/19  coffee_consumption  2254.674680
# 29  2/15/19      classroom_temp    75.000000
# 30  2/18/19      classroom_temp    55.000000
# 31  2/18/19  coffee_consumption  4819.981880
# 32  2/18/19   n_late_from_break     2.249609
# 33  2/19/19      classroom_temp    82.000000
# 34  2/19/19   n_late_from_break     4.646607
# 35  2/19/19  coffee_consumption  8628.442170
# 36  2/20/19      classroom_temp    58.000000
# 37  2/20/19   n_late_from_break     1.309552
# 38  2/20/19  coffee_consumption  6905.019190
# 39  2/21/19  coffee_consumption  1414.705560
# 40  2/21/19      classroom_temp    79.000000
# 41  2/21/19   n_late_from_break     2.132542
# 42  2/22/19      classroom_temp    68.000000
# 43  2/22/19  coffee_consumption  8894.846290
# 44  2/22/19   n_late_from_break     1.745758
# 45  2/25/19  coffee_consumption  5982.280540
# 46  2/25/19   n_late_from_break     2.344274
# 47  2/25/19      classroom_temp    84.000000
# 48  2/26/19   n_late_from_break     4.620919
# 49  2/26/19      classroom_temp    54.000000
# 50  2/26/19  coffee_consumption  9121.391370
# 51  2/27/19  coffee_consumption  4412.125900
# 52  2/27/19      classroom_temp    88.000000
# 53  2/27/19   n_late_from_break     1.860681
# 54  2/28/19   n_late_from_break     1.342123
# 55  2/28/19  coffee_consumption  1693.233410
# 56  2/28/19      classroom_temp    81.000000

# %%
pd.read_clipboard()
# Out:
#     Total  Score  10th  Grade  11th Grade.1  Converted
# 0   Total  Score  10th  Grade  11th   Grade        NaN
# 1    1520    99+   99+    920    50      34        NaN
# 2    1510    99+   99+    910    48      33        NaN
# 3    1500    99+   99+    900    47      31        NaN
# 4    1490    99+   99+    890    45      29        NaN
# ..    ...    ...   ...    ...   ...     ...        ...
# 57    960     58    41    360    1-      1-        NaN
# 58    950     56    39    350    1-      1-        NaN
# 59    940     54    38    340    1-      1-        NaN
# 60    930     52    36    330    1-      1-        NaN
# 61    320     1-    1-   None  None    None        NaN
#
# [62 rows x 7 columns]

# %%
# https://www.sjsu.edu/faculty/gerstman/StatPrimer/t-table.pdf
pd.read_clipboard()

# %% [markdown]
# ___
# # Source: A Shared Google Sheet
# 1. Get the shareable link url: `https://docs.google.com/spreadsheets/d/BLAHBLAHBLAH`**/edit#gid=**`NUMBER`
#
# 2. Turn that into a CSV export URL:
#     - Replace `/edit` with `/export`;
#     - Add `format=csv` to the beginning of the query string.
#
#         `https://docs.google.com/spreadsheets/d/BLAHBLAHBLAH`**/export?format=csv&gid=**`NUMBER`
#
# 3. Pass it to `pd.read_csv`, which can take a URL.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
csv_export_url
# Out:
# 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/export?format=csv&gid=341089357'

# %%
df_googlesheet = pd.read_csv(csv_export_url)
df_googlesheet.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ___
# # Source: CSV (Hosted or Local)

# %% [markdown]
# #### Hosted:

# %%
url = "https://gist.githubusercontent.com/ryanorsinger/bec2f59a9cef8ae7428cb70b3541354a/raw/ef64298da52e5d70f4d388f5fd48eccdb02ed3f1/ice_cream.csv"

df = pd.read_csv(url)
df.head()
# Out:
#              flavor      pints
# 0  moolenium crunch  11.057570
# 1         bubblegum   6.288724
# 2      chubby hubby   7.660815
# 3         bubblegum   6.644338
# 4        neopolitan  13.600125

# %% [markdown]
# ___
# # Source: XLS
#
# Click to download an <a href="https://osse.dc.gov/sites/default/files/dc/sites/osse/page_content/attachments/LEA%20ESSER%20Expenditure%20Data_03.10.2023.xlsx"> OSSE XLSX file</a>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <strong> Instructor Note:</strong>
#
# Have students download the item, and use either Terminal or Finder to move the file to the CWD and rename to LEA b'c it's an awful name.
#
# Open the file and explore the fact that there are MULTIPLE tabs!
#
#
# </div>

# %%
df_lea = pd.read_excel("LEA.xlsx", sheet_name="LEA Allocations", header=1)
df_lea.head()
# Out:
#    Unnamed: 0                                       LEA  \
# 0         NaN       Achievement Preparatory Academy PCS
# 1         NaN            Bridges Public Charter School
# 2         NaN        Capital City Public Charter School
# 3         NaN                       Capital Village PCS
# 4         NaN  Cedar Tree Academy Public Charter School
#
#    ESSER I - CARES (CARES_Act)  ESSER II - CRRSA (ESSER_II)  \
# 0                    462632.76                 1.819829e+06
# 1                    125224.21                 5.746787e+05
# 2                    400661.82                 1.749897e+06
# 3                     41122.97                 2.191418e+05
# 4                    144198.15                 7.274273e+05
#
#    ESSER III - ARP (ESSER_III_ARP)
# 0                     4.080082e+06
# 1                     1.288438e+06
# 2                     3.923294e+06
# 3                     4.951880e+05
# 4                     1.644761e+06

# %% [markdown]
# ___
# # Source: SQL
# Create a dataframe from the `passengers` table in the mySQL database: `titanic_db`.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#     <div class="row vertical-align">
#         <div class="col-xs-1 text-center">
#             <i class="fa fa-exclamation-triangle fa-2x"></i>
#         </div>
#         <div class="col-xs-11">
# <strong>Database Credentials</strong>
# <br>
# It's a bad idea to store your database access credentials (i.e. your username and password) in plaintext in your source code. There are many different ways one could manage secrets like this, but a simple way is to store the values in a python file that is <b>not</b> included along with the rest of your source code.
# <br>
# This is what we have done with the env module.
# <br>
# <br>
# Another option may be to create environment variables that may be called using the os library.
#             </div>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#     <div class="row vertical-align">
#         <div class="col-xs-1 text-center">
#             <i class="fa fa-exclamation-triangle fa-2x"></i>
#         </div>
#         <div class="col-xs-11">
#                 <strong> Remember:</strong>
#             Be sure to import <b>.gitignore</b> prior to pushing env.py
# </div>

# %%
def get_connection_url(db, username=env.username, host=env.host, password=env.password):
    """
    This function will:
    - take username, pswd, host credentials from imported env module
    - output a formatted connection_url to access mySQL db
    """
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

# %%
def get_connection_url(db, username=os.getenv('sqlUSER'), host=os.getenv('sqlHOST'), password=os.getenv('sqlPSWD')):
    """
    This function will:
    - take username, pswd, host credentials from imported env module
    - output a formatted connection_url
    """
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <strong> Instructor Note:</strong>
#
# This is a good opportunity to discuss calling specific functions or variables from a module, rather than just `import env` we can call all of our credentials like:
# - `from env import username, password, host`
# </div>

# %%
from env import username, password, host

def get_db_url(db):
    """
    This function will:
    - take username, pswd, host credentials from imported env module
    - output a formatted connection_url
    """
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

# %%
df = pd.read_sql('select * from passengers', get_db_url('titanic_db'))

# %%
df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %% [markdown]
# #### We will create a function that we can reference later to acquire the data:

# %%
def new_titanic_data(SQL_query):
    """
    This function will:
    - take in a SQL_query
    - create a connection_url to mySQL
    - return a df of the given query from the titanic_db
    """
    url = get_db_url('titanic_db')
    
    return pd.read_sql(SQL_query, url)

# %%
new_titanic_data('select * from passengers')
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# 0          S   Third  None  Southampton      0
# 1          C   First     C    Cherbourg      0
# 2          S   Third  None  Southampton      1
# 3          S   First     C  Southampton      0
# 4          S   Third  None  Southampton      1
# ..       ...     ...   ...          ...    ...
# 886        S  Second  None  Southampton      1
# 887        S   First     B  Southampton      1
# 888        S   Third  None  Southampton      0
# 889        C   First     C    Cherbourg      1
# 890        Q   Third  None   Queenstown      1
#
# [891 rows x 13 columns]

# %% [markdown]
# #### Store this function in a file named `acquire.py`

# %% [markdown]
# ___
# # Caching Your Data
# Because data acquisition *can take **time***, it's a common practice to write the data **locally** to a `.csv` file.
#
# 1. Do whatever you need to do to produce the dataframe that you need.
#     - For example ```df = pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))```
#     - Or your dataframe could include joins, multiple data sources, etc...
#
# <br>
#
# 2. Next, use ```df.to_csv("titanic.csv")``` to write that dataframe to the file.
# <br>
#
# 3. In your data acquisition function:
#     - First check to see if the csv file exists
#     - If it does, read from the csv file
#     - Otherwise get "fresh" data from mySQL

# %% [markdown]
# ***
# Let's work through the function creation!

# %%
os.getcwd()
# Out:
# '/Users/amandagomez/sandbox/classification/2_Data_Acquisition'

# %%
directory = '/Users/amandagomez/sandbox/classification/2_Data_Acquisition/'

# %%
os.path.exists(directory+"titanic.csv")
# Out:
# True

# %%
filename = "titanic.csv"

# %%
if os.path.exists(directory+filename): 
    df = pd.read_csv(filename)

# %%
df
# Out:
# Empty DataFrame
# Columns: [test]
# Index: []

# %%
def get_titanic_data(SQL_query, directory, filename = 'titanic.csv'):
    """
    This function will:
    - Check local directory for csv file
        - return if exists
    - if csv doesn't exist:
        - creates df of sql query
        - writes df to csv
    - outputs titanic df
    """
    if os.path.exists(directory+filename): 
        df = pd.read_csv(filename)
        return df
    else:
        df = new_titanic_data(SQL_query)

        df.to_csv(filename)
        return df

# %%
SQL_query = 'select * from passengers'
directory = '/Users/amandagomez/sandbox/classification/2_Data_Acquisition/'

# %%
get_titanic_data(SQL_query, directory)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# 0          S   Third  None  Southampton      0
# 1          C   First     C    Cherbourg      0
# 2          S   Third  None  Southampton      1
# 3          S   First     C  Southampton      0
# 4          S   Third  None  Southampton      1
# ..       ...     ...   ...          ...    ...
# 886        S  Second  None  Southampton      1
# 887        S   First     B  Southampton      1
# 888        S   Third  None  Southampton      0
# 889        C   First     C    Cherbourg      1
# 890        Q   Third  None   Queenstown      1
#
# [891 rows x 13 columns]
