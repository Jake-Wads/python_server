# %% [markdown]
# # Capstones
#
#
# ## Pre-Capstones Events
#
# 1. Capstone Proposals
#
#     - Think about and plan out what you want to do for your capstone
#
#     - Use this [Project Planning Worksheet](https://docs.google.com/document/d/1GhhJmLalk2zhzap8l-nIK7ze_3TiSEEYUJHSs7lJqOU/edit?usp=sharing) to help guide your proposal formation
#
#     - By or before the due date given to you, [use this form to submit your capstone project proposals](https://docs.google.com/forms/d/e/1FAIpQLSdTPc_og2Q8BOXTSSmdUpRay_aLKNAakD9MoT68uYENTyR65A/viewform?usp=sf_link)
#
#     - Proposals are submitted anywhere from 1-2 weeks prior to the kickoff of capstones.
#
#
# 2. Instructors will curate projects and iron out details with project submission authors. Not all proposals will be selected to be pitched. Those that are most likely to lead to success of each team member are the ones selected!
#
#
# 3. Capstone Pitches to the class and project preferences are collected from students.
#
#
# 4. Capstone Kickoff and team announcements.
#
#
#
# ## What to expect during Capstones
#
# - ALL PLANNING for at least day 1
# - Daily standup meetings with instructors
#     - documentation of standups
# - Trello board for all tasks
# - Knowledge share document with the team
# - Multiple daily check-ins
#
#
# ## Final Deliverables
#
# Required:
#
# - A clean repo with a professional final notebook and README
# - A 7-10 minute presentation with slides
#
# Some additional, optional ideas:
#
# - Pamphlet/handout of results
# - White paper draft of project
# - Interactive Data Dashboard
# - Webpage for your project or web-application
#
#
#
# ## Timeline
#
# - Day 01: Kickoff and project planning
# - Day 02: Wrap up project planning, acquire and prepare data
# - Day 03: Data acquisition, prep, exploration, and modeling
# - Day 04: Data acquisition, prep, exploration, and modeling
# - Day 05: Data acquisition, prep, exploration, and modeling
# - Day 06: Finish MVP, including slide deck
# - Day 07: No starting anything new, only wrapping up existing stuff
# - Day 08: Wrap up Project
# - Day 09: Work on Presentation
# - Day 10: Fix any bugs/issues
# - Day 11: Review Panel 1 (with DS Instructors/Some Staff)
# - Day 12: Project Polish
# - Day 13: Review Panel 2 (with another DS Cohort)
# - Day 14: Review Panel 3 (with Codeup staff)
# - Day 15: Graduation Day

# %% [markdown]
# ## Project Management of Capstones
#
# We will pull pieces from scrum and kanban, an agile software development lifecycle methodology
#
# For background, the Software Development Lifecycle (SDLC) includes:
#
# 1. Planning
# 1. Analysis
# 1. Design
# 1. Implementation
# 1. Maintenance
#
# There are different methodologies for working through these stages. Agile and waterfall are 2 major schools of thought. Within Agile are methodologies such as scrum and kanban.
# The three ideas we will make the most use of here are the scrum or kanban board (via trello), starting with larger stories and breaking them into clearly defined tasks that can be tackled quickly, and daily standups.
# See the Agile Manifesto.
#
# ### Daily standups (no more than 15 mins)
#
# Each morning, your team will have a standup meeting with the instructors. In that meeting, each team member will answer the following questions:
#
# 1. What did you work on since the last standup?
# 2. What are you planning on working on next / working on now?
# 3. What are your blockers (technical, personal, etc)?
#
# We don't solve problems during the standup but we identify problems and will schedule time to solve.
# Before each standup, make sure your trello board is updated, meaning all cards are in the correct columns and all known tasks have been converted to trello cards.
#
# ### The Trello Board
#
# Your trello board should have the following columns:
#
# - **Stories:** DS Pipeline stages, e.g. project planning, data acquisition, ...
# - **Backlog:** Create tasks out of those stories and store them in the backlog. If a task is not getting you closer to your final goal in one way or another, then it shouldn't be a task.
# - **Next up:** Each morning, pull the next priority tasks into this column which will be what you will pull from when you are ready for a new task.
# - **In progress:** What you are currently working on. If you are working on something, it should be in your name and should be in the "in progress" column. Given that we are humans and are incapable of multitasking, you should not have 2 cards with your name on them "in progress" simultaneously.
# - **Ready for testing:** When you finish a task, update the card by moving it here before moving on. When you see a card in ready for testing on a task that you did not work on, pick it up, move it to testing, and test or review as appropriate. When you have confirmed it passes, move to done. If it is not done or something needs to be corrected, put it back in "next up" with notes of what needs correcting.
# - **Done:** a task is done when it has been completed and confirmed. If further questions develop out of the task, a new task should be created. Do not continue using the same card if new questions arise! If you continue updating the same card, you will get lost down holes and feel like you never accomplish anything and that can be very discouraging, among other reasons.
#
# !!!tip "Project Management with Trello"
#     If it's not a task in trello, you don't need to be working on it. If you need to be working on it, it needs to be a task in trello.
#
#     This might seem a little bureaucratic, but is extremely common practice in the workplaces. Some workplaces are even more extreme in that all working hours must be tied to, for example, a specific ticket or issue in a project management system.
#
# Here is an example of a group's capstone project trello board:
#
# ![sample_trello_board.png](sample_trello_board.png)
#
#
# ### Other communication:
#
# In addition to daily standups w/ instructors your team should have team meetings in the morning, after lunch, and before you leave for the day. If this feels like too much, you can always stop having a meeting, but it's easier to start with more meetings and cut back on the number of meetings than it is to go in the other direction.

# %% [markdown]
# ## Retrospectives from Previous Cohorts
#
# Assorted thoughts from past students on the keys to success!
#
# Planning:
#
# - Planning! The more planning, the more we can accomplish.
# - who's strong in what, sharing the work, divide and conquer
# - get a good solid understanding of the industry, where you're going, why you're doing it.
# - Defining MVP/ providing clarity on deliverables
# - Splitting up work
#
# Wrangle:
#
# - you don't have to wait for the dataset to be perfect before you move on to the next step.
# - create different versions of wrangling for exploration so you don't have to recreate it over and over again.
#
#
# Explore:
#
# - Clearly state your questions throughout exploration and answer them
# - make headers in exploration/visualization questions to be answered so you can lead your audience and yourself
# - label charts as you go so you don't have to go back and do that for
# - write out hypothesis before testing
#
# Model:
#
# - use what you learned in exploration to improve your model
#
# README:
#
# - work on your readme in the beginning
# - work on readme as you go
# - Detailed readme
#
# Presentation:
#
# - work on your presentation as you go
# - Build slides as you go...get the information on the slides, you can edit/remove later.
#
#
# Writing code:
#
# - name functions relevant to what the function does
# - doc strings for functions as soon as you write them!
# - don't write a "mother function"! write a bunch of little functions
# - annotate what i'm doing in the notebook with markdown, write out the thought process
# - refactoring comes after a working product
# - sometimes things just don't work, and you have to move on!
# - maybe it just doesn't work because it doesn't work. Validate with peers though.
# - don't try to perfect the code, it can always better
# - don't try to make something work that you already know at some level is not going to work
# - if it works, it works
#
#
# Workflow:
#
# - focus on the mvp
# - Getting an MVP (it’s the data product deliverable, not just code that runs)
# - communicating to avoid merge conflicts. let your partner know if you did a push in the middle of night
# - disable autosave on notebooks
# - make standard notebooks acquisition_test.ipynb, and add in gitignore so they never get pushed. Keeps everything clean and everyone's indiv work separate
# - Separate working notebook to avoid merge conflicts
# - separate folders in the repo for each person as working to avoid merge conflicts
# - don't delete the old work
# - don't sit struggling for too long, if you can't figure it out, reach out to partner
# - get a good night's sleep
# - take a lot of breaks
# - don't forget to have fun
# - begin with the end in mind
# - figure out how to get back on track
# - don't get too emotionally invested, take a step back
# - Be nice to your body and brain throughout the process (get good sleep)
# - Take team breaks and look out for each other. Also take breaks away from your team as needed
# - Trusting your team and taking advantage of diverse strengths
# - Early and frequent communication
#
# #### Challenges previous students have faced
#
# - Lack of communication in process
# - Unannounced deviations / project scope creep
# - Lack of planning
# - Lack of milestones
# - Lack of testing
# - Not enough buffer time to iterate effectively
# - Insufficient early exploration
# - Rabbit holes
# - No clear conclusions from exploration / lack of tying it all together
# - Lack of documentation and commenting as you go
#
#
#
#
# ## Examples of past Capstones and the format
# - [https://github.com/3-1-1-Codeup/project](https://github.com/3-1-1-Codeup/project)
# - [https://github.com/Fake-News-Capstone/fake_news_capstone](https://github.com/Fake-News-Capstone/fake_news_capstone)
# - [https://github.com/MG-Squared/americas_blues](https://github.com/MG-Squared/americas_blues)
# - [https://github.com/curie-capstone/predicting-patient-outcomes](https://github.com/curie-capstone/predicting-patient-outcomes)
# - [https://github.com/just-keep-spinning/hard-drive-project](https://github.com/just-keep-spinning/hard-drive-project)
# - [https://github.com/Texas-Government-Employee-Salaries/Predicting-Salaries](https://github.com/Texas-Government-Employee-Salaries/Predicting-Salaries)
# - [https://github.com/Attention-Walmart-Shoppers/capstone](https://github.com/Attention-Walmart-Shoppers/capstone)
# - [https://github.com/OTR-Capstone/Off_The_Rails](https://github.com/OTR-Capstone/Off_The_Rails)
# - [https://github.com/Germain-Drug-Discovery-Project/drug-discovery-project](https://github.com/Germain-Drug-Discovery-Project/drug-discovery-project)
# - [https://github.com/stroke-predictors/germain-capstone-stroke-prediction](https://github.com/stroke-predictors/germain-capstone-stroke-prediction)
# - [https://github.com/american-perspectives-capstone/american-attitudes](https://github.com/american-perspectives-capstone/american-attitudes)
