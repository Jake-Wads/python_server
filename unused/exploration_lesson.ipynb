# %%
import acquire
import prepare
import pandas as pd
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = acquire.get_titanic_data()
df = prepare.prep_titanic_data(df)

# %%
df = df.dropna()

# %%
train, test = train_test_split(df, test_size=.3, random_state=123, stratify=df[['survived']])

# %%
survival_rate = train.survived.mean()*100

p = train.survived.value_counts().plot(kind="bar", alpha=.5)
p.set_ylabel('Survival')
p.axhline(survival_rate, ls='--', color='gray')

# %%
train.survived.value_counts()
# Out:
# 0    296
# 1    203
# Name: survived, dtype: int64

# %%
203/296
# Out:
# 0.6858108108108109

# %%
features = ['sex', 'class', 'alone']

_, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,5))

survival_rate = train.survived.mean()

for i, feature in enumerate(features):
    sns.barplot(feature, 'survived', data=train, ax=ax[i], alpha=.5)
    ax[i].set_ylabel('Survival Rate')
    ax[i].axhline(survival_rate, ls='--', color='grey')
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot('sex', 'survived', data=train, hue='alone')
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
train.groupby(['sex','alone'])['survived'].count()
# pd.crosstab(train.sex, train.alone, margins=True).style.background_gradient(cmap='YlOrRd')
# Out:
# sex     alone
# female  0        112
#         1         65
# male    0        107
#         1        215
# Name: survived, dtype: int64

# %%
train.columns
# Out:
# Index(['passenger_id', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'embark_town', 'alone', 'embarked_encode'],
#       dtype='object')

# %%
features = ['sex', 'class', 'embarked']

_, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,5))

survival_rate = df_family.survived.mean()

for i, feature in enumerate(features):
    sns.barplot(feature, 'survived', data=df_family, ax=ax[i], alpha=.5)
    ax[i].set_ylabel('Survival Rate')
    ax[i].axhline(survival_rate, ls='--', color='grey')
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pd.crosstab(df_family['class'], df_family.embarked, margins=True).style.background_gradient(cmap='YlOrRd')
# Out:
# <style  type="text/css" >
#     #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col0 {
#             background-color:  #feab49;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col1 {
#             background-color:  #fece6a;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col2 {
#             background-color:  #ffffcc;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col3 {
#             background-color:  #fff3ae;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col0 {
#             background-color:  #ffffcc;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col1 {
#             background-color:  #ffffcc;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col2 {
#             background-color:  #fffac1;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col3 {
#             background-color:  #ffffcc;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col0 {
#             background-color:  #fee187;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col1 {
#             background-color:  #ea2920;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col2 {
#             background-color:  #ffe48c;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col3 {
#             background-color:  #fee289;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col0 {
#             background-color:  #800026;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col1 {
#             background-color:  #800026;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col2 {
#             background-color:  #800026;
#         }    #T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col3 {
#             background-color:  #800026;
#         }</style>
# <table id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00" >
# <thead>    <tr>
#         <th class="index_name level0" >embarked</th>
#         <th class="col_heading level0 col0" >C</th>
#         <th class="col_heading level0 col1" >Q</th>
#         <th class="col_heading level0 col2" >S</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00level0_row0" class="row_heading level0 row0" >First</th>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col0" class="data row0 col0" >24</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col1" class="data row0 col1" >2</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col2" class="data row0 col2" >46</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row0_col3" class="data row0 col3" >72</td>
#     </tr>    <tr>
#         <th id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00level0_row1" class="row_heading level0 row1" >Second</th>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col0" class="data row1 col0" >8</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col1" class="data row1 col1" >0</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col2" class="data row1 col2" >50</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row1_col3" class="data row1 col3" >58</td>
#     </tr>    <tr>
#         <th id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00level0_row2" class="row_heading level0 row2" >Third</th>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col0" class="data row2 col0" >16</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col1" class="data row2 col1" >5</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col2" class="data row2 col2" >68</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row2_col3" class="data row2 col3" >89</td>
#     </tr>    <tr>
#         <th id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col0" class="data row3 col0" >48</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col1" class="data row3 col1" >7</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col2" class="data row3 col2" >164</td>
#         <td id="T_b27ab0a2_525b_11e9_9200_8c8590a0fd00row3_col3" class="data row3 col3" >219</td>
#     </tr></tbody>
# </table>

# %%
train.columns
# Out:
# Index(['passenger_id', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'embark_town', 'alone', 'embarked_encode'],
#       dtype='object')

# %%
features = ['sibsp', 'parch', 'survived']

_, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,5))

survival_rate = df_family.survived.mean()

for i, feature in enumerate(features):
    sns.barplot(feature, 'survived', data=df_family, ax=ax[i], alpha=.5)
    ax[i].set_ylabel('Survival Rate')
    ax[i].axhline(survival_rate, ls='--', color='grey')
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pd.crosstab(df_family.sibsp, df_family.parch, margins=True).style.background_gradient(cmap='YlOrRd')
# Out:
# <style  type="text/css" >
#     #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col0 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col1 {
#             background-color:  #fec863;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col2 {
#             background-color:  #fec45f;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col3 {
#             background-color:  #fed976;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col4 {
#             background-color:  #febf5a;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col5 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col6 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col7 {
#             background-color:  #ffe48c;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col0 {
#             background-color:  #c50624;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col1 {
#             background-color:  #fd863a;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col2 {
#             background-color:  #fedd7e;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col3 {
#             background-color:  #fd8c3c;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col4 {
#             background-color:  #f43d25;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col5 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col6 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col7 {
#             background-color:  #fc5d2e;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col0 {
#             background-color:  #ffec9f;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col1 {
#             background-color:  #fff8ba;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col2 {
#             background-color:  #fff9bd;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col3 {
#             background-color:  #fed976;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col4 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col5 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col6 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row2_col7 {
#             background-color:  #fff3af;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col0 {
#             background-color:  #fffcc4;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col1 {
#             background-color:  #fffcc4;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col2 {
#             background-color:  #fff2ac;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col3 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col4 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col5 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col6 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row3_col7 {
#             background-color:  #fffac0;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col0 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col1 {
#             background-color:  #fff0a8;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col2 {
#             background-color:  #fff2ac;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col3 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col4 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col5 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col6 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row4_col7 {
#             background-color:  #fff7b9;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col0 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col1 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col2 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col3 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col4 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col5 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col6 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row5_col7 {
#             background-color:  #ffffcc;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col0 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col1 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col2 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col3 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col4 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col5 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col6 {
#             background-color:  #800026;
#         }    #T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row6_col7 {
#             background-color:  #800026;
#         }</style>
# <table id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00" >
# <thead>    <tr>
#         <th class="index_name level0" >parch</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >sibsp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col0" class="data row0 col0" >0</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col1" class="data row0 col1" >24</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col2" class="data row0 col2" >16</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col3" class="data row0 col3" >1</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col4" class="data row0 col4" >1</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col5" class="data row0 col5" >0</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col6" class="data row0 col6" >0</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row0_col7" class="data row0 col7" >42</td>
#     </tr>    <tr>
#         <th id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col0" class="data row1 col0" >71</td>
#         <td id="T_4d5736f0_523d_11e9_8fe9_8c8590a0fd00row1_col1" class="data row1 col1" >40</td>

# %%
# 3. violin plot
features = ['sibsp', 'parch']
feature_count = range(len(features))

_, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

for i, feature in enumerate(features):
    sns.violinplot(feature, 'age', hue='survived',
        data=df_family, split=True, ax=ax[i], palette=['blue','orange'])
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 3. violin plot

sns.violinplot('sibsp', 'parch', hue='survived', 
               data=df_family, split=True, palette=['blue','orange'])
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# for those traveling with family:
# > 3 children - less likely
# 3 children - more likely
# traveling with spouse only - less likely
# 0 parch, 1 sibsp - likely to be traveling as a couple
# 0 sibsp - more likely to survive

# %%
train.sex.value_counts()
# Out:
# male      322
# female    177
# Name: sex, dtype: int64

# %%
_, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

for i, value in enumerate(['male','female']):
    ax[i].set_title(value)
    sns.swarmplot(x="alone", y="age", hue="survived",
                 palette=["r","c","y"], ax=ax[i], data=train[train['sex']==value])

# %%
# Draw a categorical scatterplot to show each observation
sns.swarmplot(x="alone", y="age", hue="survived", 
              palette=["r", "c", "y"], ax=ax[0], data=train[train['sex']=='female'])
sns.swarmplot(x="alone", y="age", hue="survived", 
              palette=["r", "c", "y"], ax=ax[1], data=train[train['sex']=='male'])
