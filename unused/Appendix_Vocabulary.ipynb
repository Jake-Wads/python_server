# %% [markdown]
# http://jukebox.esc13.net/untdeveloper/RM/RM_FR_P2/RM_FR_P22.html
#
# #### VCS/DVCS: (Distributed) Version Control System
#
# #### repository
#
# project managed with git, a folder and all the files/contents within that folder.  All respositories are folders but not all folders are repositories
#
# #### Git
# Version control system
#
# #### Github
#
# A version control system, a place for us to store our repositories in the cloud.  A portfolio for anyone who writes code.
#
#
# #### Regression
#
# strength of the relationship between a dependent variable (Y) and a series of other changing, independent variables.
#
# #### Single Variable Linear Regression
#
# models the relationship between a single input independent variable (feature variable) and an output dependent variable using a linear model, i.e a line.
#
# #### Multi-Variable Linear Regression
#
# models the relationship between multiple independent input variables (feature variables) and an output dependent variable. The model remains linear in that the output is a linear combination of the input variables.
#
# #### Polynomial Regression
#
# models the non-linear relationship of the independent variables and the dependent variable. For example, the relationship could follow a sine, cosine, exponential, logrithmic, or quadratic function, to name a few.
#
# #### Supervised Machine Learning
#
# Supervised learning is the machine learning task of learning a function that maps an input to an output based on example input-output pairs. It infers a function from labeled training data consisting of a set of training examples.
#
# Stated another way, by Jason Brownlee https://machinelearningmastery.com/supervised-and-unsupervised-machine-learning-algorithms/
#
# Supervised learning is where you have input variables (x) and an output variable (Y) and you use an algorithm to learn the mapping function from the input to the output.
#
# $$y = f(X)$$
#
# The goal is to approximate the mapping function so well that when you have new input data (x) that you can predict the output variables (Y) for that data.
#
# It is called supervised learning because the process of an algorithm learning from the training dataset can be thought of as a teacher supervising the learning process. We know the correct answers, the algorithm iteratively makes predictions on the training data and is corrected by the teacher. Learning stops when the algorithm achieves an acceptable level of performance.
#
# #### Structured Data
#
# Data that has been organized into a formatted repository, like a database, for more effective processing and analysis. A data structure is a kind of repository that organizes information for that purpose.
# https://whatis.techtarget.com/definition/structured-data
#
# #### Relational Database Management System
#
# A relational database management system is a database management system based on the relational model of data. Most databases in widespread use today are based on this model.  It stores data in a structured format, using rows and columns.
#
# #### Feature/Independent Variable
#
# an individual measurable property of a phenomenon being observed.
#
# #### Dependent Variable
#
# The dependent variable is what is being studied and measured in the experiment. It's what changes as a result of the changes to the independent variable. The values of dependent variables depend on the values of independent variables.
#
# #### Sum of Squared Error
#
# a.k.a. the residual sum of squares, the sum of squared residuals.  It is a measure of the discrepancy between the data and an estimation model. A small RSS indicates a tight fit of the model to the data.
#
# #### Coefficient of Determination
#
# aka R-Squared, measures the fraction of the total variation in the dependent variable that is captured by the model.
#
# #### Classifier
# An algorithm that maps the input data to a specific category.
#
# #### Classification model
# series of steps that take the patterns of input variables, generalize those patterns, and apply to new data in order to predict the class.
#
# #### Feature
# A feature, aka input/independent variable, is an individual measurable property of a phenomenon being observed.
#
# #### Binary Classification
# Classification with two possible outcomes. e.g. pass/fail
#
# #### Multi class classification
# Classification with more than two classes, where each sample is assigned to one and only one target label. e.g. Students' grade level in school (1st-12th) ### What are classification algorithms?
#
# #### REPL: Read Evaluate Print Loop
# interactive, starts a python interpreter that's interactive
